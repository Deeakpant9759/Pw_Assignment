# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeakpant9759/Pw_Assignment/blob/master/Python_OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Python OOPs Questions***

# %% [markdown]
# Question 1: What is Object-Oriented Programming (OOP)?
#
# Answer 1:Object oriented prgramming in paradigm based on objects , which combines  attributes and method into a single unit which allows code to be more structured  and resuable and easy to maintian .
#
# in simple words oop is way of coding where we mange all things in a single unit example a car full structre and form the sturctre we decide our type of brand of menas in oop object. form a car we can create multipal brand (BMW,TOYOTA,ETC) But they are part of a car or vhicale same of oops. we crated a single unit class now can instaciate multipal object of that.

# %% [markdown]
# Question 2: What is a class in OOP?
#
# Answer 2:In oop class is the blue print or the templete that defines about the attributes or method that object will have.
#
# In simple word class is like the plan or design. like a mold where as per the matrial the obejct will come out but the mold remains same.

# %% [markdown]
# Question 3: What is an object in OOP?
#
# Answer 3:Object is oop is a intance of a class which can access the mehtods or attributed difined by the class.
#
# In simple words, an object is a real thing created from a class. The class is just a blueprint or map, but the object is the real thing with actual values.
# For example, a map may show cars, buildings, and more but the objects are the real car and the real building created from that blueprint.

# %% [markdown]
# Question 4: What is the difference between abstraction and encapsulation?
#
# Answer 4: Abstraciton is the process where we hide complex implmentation only show the essential features of an object but in encapsulaiton we restrict the the attribuetes and method of class accessing by outside of class.

# %% [markdown]
# Question 5: What are dunder methods in Python?
#
# Answer 5: dunder menas duble undersocre(__ _double_underscores___) they are spical predefiend mehtods that python class automatical in certain sutations
#
# example "_ _init_ _" when create a class and initate with __init__ so python will excute this first no matter what. and inside this will be excutated automaticly.

# %% [markdown]
# Question 6: Explain the concept of inheritance in OOP
#
# Answer 6:Inheritance in oops refers to the attributes and method of a class are inherited by  another class in a manner.
#
# They follow parent and child structure like we define a class that would be parent class then after another class. we pass that class inside the another class menas child class so the child class will inheriet all the methods or quility of the parent class

# %% [markdown]
# Question 7: What is polymorphism in OOP?
#
# Answer 7: Polymoriphism in oops: poly menas many and morph menas form menas which can take many form.
#
# in simple words one funciton or method can behave diffrently on the object calling.
#
# example:
# class Animal:
#     def speak(self):
#         print("Animal makes a sound")
#
# class Dog(Animal):
#     def speak(self):
#         print("Dog barks")
#
# class Cat(Animal):
#     def speak(self):
#         print("Cat meows")
#
# class Cow(Animal):
#     def speak(self):
#         print("Cow moos")
#
# animals = [Dog(), Cat(), Cow()]
#
# for animal in animals:
#     animal.speak()
#
# Dog barks
# Cat meows
# Cow moos
# All classes share the same method name → speak().
#
# Each class defines it differently → different sounds.
#
# The loop does not care which animal it is — it just calls speak().
#
# That is polymorphism: one interface (speak) → many forms (different behaviors).

# %% [markdown]
# Question 8: How is encapsulation achieved in Python?
#
# Answer 8:There are there type of encapsulaition. Public , protected and private.  to active each there are diffrent method. for public just wirte the varible name for protected we have pass a single undersocre in fornt of the varible or  attribute and for private we have pass dubble underscore in fornt of the variblale.
#
# the Use of Pulbic , protected and private.
#
# Public: variable: can access everwhere
#
# private: _variable(single underscore): can access within class or sublclass
#
# protected: _ _variable(dubble underscore):only accessible inside the class

# %% [markdown]
# Question 9: What is a constructor in Python?
#
# Answer 9: Constructor in pyhton are spacil methods use to initialize objects. when we create a class in python so we want excute some sort of varible or code automaticly . then we use constructor we have constructor name _ _init_ _  in python . when we creat it. It will excute automticly.
#
# so in short usually to assign values to object variables we use constructor in python.
#
# example:
#
# _ _ init _ _(self):
# here our construcuor is defined

# %% [markdown]
# Question 10: What are class and static methods in Python?
#
# Answer 10: Class methods are used to access the class varible in python so they don't care about the objects they wrok with the class itself we declare to them by using @classmtheod before the mehtod to whihc we wnat to access the class varible .  and they not take the self argument we pass cls argument.
#
# in simple words they are used ot modify class varible whihc is shared by all object.
#
# Static methods are those methods in python whihc  don't care about the attributes and method of class they are differnt entity by them self. they don't need any data or mathods of class to make them.
# we make them by using @staticmethod before the fucntion.
#
# in simple words they are like utility fucniton or helper funciotn in class which don't need any data form class or self, or cls still they can exceute and give the asnwer

# %% [markdown]
# Question 11: What is method overloading in Python?
#
# Answer 11:method overloading menas having multipal methods  with the same name but with diffrent parameters. so they can perform deffrent task depending what kind of arrguments u pass into them.
#
# in short same method name. diffrent bheaviour on input
#
# example  :
# class MathOperation:
#     def multiply(self, *args):
#         result = 1
#         for num in args:
#             result *= num
#         return result
#
# create object
# m = MathOperation()
#
# print(m.multiply(5))          # output: 5
# print(m.multiply(2, 3))       # output: 6
# print(m.multiply(2, 3, 4))    # output: 24

# %% [markdown]
# Question 12: What is method overriding in OOP?
#
# Answer 12:method overrding menas when a fucncition of child class changes the bheviour of method of a prent class called method overriing.
#
# in simple wrods same method name same parameters with diffrent class.
#
# example:
#
#
# class Parent:
#     def greet(self):
#         print("hello from parent")
#
# class Child(Parent):
#     def greet(self):    # child overriding parent
#         print("hello from child")
#
# c = Child()
# c.greet()  # output: hello from child

# %% [markdown]
# Question 13: What is a property decorator in Python?
#
# Answer 13:The @property decorator in python is use when we want to acess a method like normal varible. it help to hide the data and control how value is read or change. it is use for encapulation so we dont call get or set method again and again.
#
# in simple word it make method look like attrbute and we can also add check using setter.

# %% [markdown]
# Question 14: Why is polymorphism important in OOP?
#
# Answer 14:Polymorphism in important because it help us to make our code resuable an flexible it reduces the redunancy of the code we can write a code where a same mehtod can work deffrent on the input.
#
# in simple words it makes programs easier to extend, manage, and maintain by allowing the same function name to work with different classes.

# %% [markdown]
# Question 15: What is an abstract class in Python?
#
# Answer 15:abstract class in python is a blueprint for otherclass to follow while inheriting the properties of that class without following the blueprint program will through an error.
#
# for example:
# like a bank system a perons want to deposit a money and what withdraw so there are some rules in both case must follow like he shoul be the momber of bank and many other security point so there come abstract class it helps us to make a code now ever other clss whihc have inherited the class have to follow the blueprint. or guide of the abstract class.

# %% [markdown]
# Question 16: What are the advantages of OOP?
#
# Answer 16: OOP helps us to make code into well structure manner. for a analogy suppose storing cloths in couture we have diffrent type of cloths we have no any seciton for them it iwll hard to find or maintian the cloths .
#
# here the oops come it make a proper seciotn of a spacifc cateogry like banking system i can maintin dcuments,accounting,trancastions in deffrent deffrent seciotn in future i have to change any thing that would be suuper easy.
#
# in other words:
# reusability
#
# modularity
#
# data security (encapsulation)
#
# flexibility (polymorphism)
#
# easy maintenance
#
# inheritance
#
# real-world modeling
#
# extensibility

# %% [markdown]
# Question 17: What is the difference between a class variable and an instance variable?
#
# Answer 17: Class varible is shared by all the object of the class but instance is unique for every object.
#
# calss varible is defiend inside class but not in  or under the method  instance  varible is defiend inside the method or  the constructor init() .
#
# class varible are accessed by using classname.classvarible but the instance are used by self.variblename

# %% [markdown]
# Question 18: What is multiple inheritance in Python?
#
# Answer 18: multiple inhertance menas a child class have have properties of diffrent class at same time
#
# example : class in mother and father so the child class have properties of both mother and father
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 19: Explain the purpose of 'str' and 'repr' methods in Python
#
# Answer 19: str is used to print or return readable  or human frendly strings represenation of an object
# is is mainly used when you print the object using print() or str().
#
# repr return an devloper friendly string of an oject one that could ideally be used to recreate the object
#
# Example:
# code:
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def __str__(self):
#         return f"{self.name}, {self.age} years old"
#
#     def __repr__(self):
#         return f"Person('{self.name}', {self.age})"
#
# p = Person("Deepak", 20)
#
# print(str(p))
# print(repr(p))
#
#
# Deepak, 20 years old # returned by str
# Person('Deepak', 20) # return by repr

# %% [markdown]
# Question 20: What is the significance of the 'super()' function in Python?
#
# Answer 20:Super() is  used in inheritance. where child class can call the method of the parent class even after overriding it.
#
# in short it gives access to the paren't varsion of that method.
#
# example:
#
# class Animal:
#   def sound(self):
#     print("Hello from Animal")
#
# class Cow(Animal):
#   def sound(self):
#     super().sound()   # calls parent class method
#     print("Moo from Cow")

# %% [markdown]
# Question 21: What is the significance of the del method in Python?
#
# Answer 21:del is spacial or magic method in python whihc runs automatic when an object is created form the class it allows us to delete a object or distroy  the object.
#
# in simple words used to renove object form  the memory

# %% [markdown]
# Question 22: What is the difference between @staticmethod and @classmethod in Python?
#
# Answer 22:the @staticmethod in python is a method that does not take any default first argument like self or cls. it works independently of class or object data and is mainly used for utility or helper functions that perform a specific task. it cannot access or modify class or instance variables.
#
# the @classmethod, on the other hand, takes cls as its first argument and can access or modify class variables but not instance variables. it is used when you want a method to work with the class as a whole rather than individual objects. both can be called using the class name or an object, but their use depends on whether the method needs access to class data or not.

# %% [markdown]
# Question 23: How does polymorphism work in Python with inheritance?
#
# Answer 23: in inheritance it allows to child class to override the method of the parent class so it allows child class to have its own version of that method which was in parent class
#
# Eaxample:
# class Animal:
#     def sound(self):
#         print("Some generic animal sound")
#
# class Dog(Animal):
#     def sound(self):
#         print("Dog barks")
#
# class Cat(Animal):
#     def sound(self):
#         print("Cat meows")
#
#   animals = [Dog(), Cat(), Animal()]
#
# for a in animals:
#     a.sound()
#
#
# Dog barks
# Cat meows
# Some generic animal sound

# %% [markdown]
# Question 24: What is method chaining in Python OOP?
#
# Answer 24:Mehtod chaining in python menas to call the method of the class of the python sequantily means in a single line all the  method of the class to  do that we have to return self in ever method
#
# example  noramally:
#  obj.method1()
# obj.method2()
# obj.method3()
#
# method chaing:
# obj.method1().method2().method3()
# works only wehn each method return self

# %% [markdown]
# Question 25: What is the purpose of the call method in Python?
#
# Answer 25:The __call__ method in python is used to make an object act like a function. when we define this method inside a class, we can call the object directly using parentheses like a normal function. it allow us to add custom behavior when object is “called”.
#
# class Greet:
#   def __init__(self, name):
#     self.name = name
#
#   def __call__(self):
#     print(f"Hello {self.name}!")
#
# g = Greet("Deepak")
# g()
#
# Hello Deepak!

# %% [markdown]
# # **Practical OOP Questions:**

# %% [markdown]
# Question 1: Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!". Answer:

# %%
class Animal:
  def speak(self):
    print("Animal makes a sound")

class Dog(Animal):
  def speak(self):
    print("Dog barks")

obj = Dog()
obj.speak()
# Out:
# Dog barks

# %% [markdown]
# Question 2: Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both. Answer:

# %%
from abc import ABC, abstractmethod
class Shape:
  @abstractmethod
  def area(self):
    pass
class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius
  def area(self):
    return 3.14*self.radius**2
class Rectangle(Shape):
  def __init__(self,length,breath):
    self.length = length
    self.breath = breath

  def area(self):
    return self.length*self.breath

  def parameter(self,l ,b):
    return 2*(l+b)
circle = Circle(5)
rectangle = Rectangle(4,6)
rct = Rectangle(5,6)
print(rct.parameter(4,6))
print(circle.area())
print(rectangle.area())
# Out:
# 20
# 78.5
# 24

# %% [markdown]
# Question 3: Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute. Answer:

# %%
class Vehicle:
  def __init__(self,type):
    self.type = type
class Car(Vehicle):
  def __init__(self,type,model):
    super().__init__(type)
    self.model = model
class ElectricCar(Car):
  def __init__(self,type,model,battery):
    super().__init__(type,model)
    self.battery = battery
  def show_details(self):
      print(f"Type: {self.type}")
      print(f"Brand: {self.model}")
      print(f"Battery Capacity: {self.battery} kWh")

# Object creation
tesla = ElectricCar("Four Wheeler", "Tesla", 85)
tesla.show_details()
# Out:
# Type: Four Wheeler
# Brand: Tesla
# Battery Capacity: 85 kWh

# %% [markdown]
# Question 4: Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method. Answer:

# %%
class Bird:
  def fly(self):
    print("Birds are flying")
class Sparrow(Bird):
  def fly(self):
    print("Sparrows can fly")
class Penguin(Bird):
  def fly(self):
    print("Penguins cannot fly")
sparrow_obj = Sparrow()
penguin_obj = Penguin()
sparrow_obj.fly()
penguin_obj.fly()
# Out:
# Sparrows can fly
# Penguins cannot fly

# %% [markdown]
# Question 5: Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance. Answer:

# %%
class BankAccount:
  def __init__(self,balance):
    self.__balance = balance
  def deposit(self,amount):
    if amount > 0:
      self.__balance +=amount
      print(f"Amount added to account {amount}")
    else:
      print("Invalid amount")
  def withdraw(self,amount):
    if amount > 0 and amount <= self.__balance:
      self.__balance-=amount
      print(f"Amount withdrawed {amount}")
    else:
      print("Invalid Amount")
  def check_balance(self):
    return self.__balance

account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
print(account.check_balance())
# Out:
# Amount added to account 500
# Amount withdrawed 200
# 1300

# %% [markdown]
# Question 6: Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play(). Answer:

# %%
class Instrument:
  def play(self):
    print("Instrument is playing")
class Guitar(Instrument):
  def play(self):
    print("Guitar is playing")
class Piano(Instrument):
  def play(self):
    print("Piano is playing")
guitar = Guitar()
piano = Piano()
guitar.play()
piano.play()
# Out:
# Guitar is playing
# Piano is playing

# %% [markdown]
# Question 7: Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers. Answer:

# %%
class MathOperations:
  x =5
  y = 3
  @classmethod
  def add_numbers(cls):
    return cls.x + cls.y
  @staticmethod
  def substract_number(a,b):
    return b-a

m1 = MathOperations()
print("Added numbers",m1.add_numbers())
print("substracted numbers",m1.substract_number(3,7))
# Out:
# Added numbers 8
# substracted numbers 4

# %% [markdown]
# Question 8: Implement a class Person with a class method to count the total number of persons created. Answer:

# %%
class Person:
  count = 0
  def __init__(self,name):
    self.name = name
    Person.count +=1
  @classmethod
  def total_persons(self):
    print(f"total perons created {self.count}")
p1 = Person("Deepak")
p2 = Person("Rohan")
p3 = Person("Meera")

# Call class method
Person.total_persons()
# Out:
# total perons created 3

# %% [markdown]
# Question 9: Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator". Answer:

# %%
class Fraciton:
  def __init__(self,numerator,denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

fraction = Fraciton(9,5)
print(fraction)
# Out:
# 9/5

# %% [markdown]
# Question 10: Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors. Answer:

# %%
class Vector:
  def __init__(self,x,y):
    self.x=x
    self.y =y
  def __add__(self,other):
    return Vector(self.x+ other.x,self.y+other.y)
  def __str__(self):
    return f"({self.x},{self.y})"
v1= Vector(1,2)
v2 =Vector(3,4)
print(v1+v2)
# Out:
# (4,6)

# %% [markdown]
# Question 11: Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old." Answer:

# %%
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def greet(self):
    print(f"Hello , my name is {self.name} an i am {self.age} years old")
obj = Person("Deepak",3)
obj.greet()
# Out:
# Hello , my name is Deepak an i am 3 years old

# %% [markdown]
# Question 12: Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades. Answer:

# %%
class Student:
  def __init__(self,name ,grades) -> None:
    self.name = name
    self.grades= grades
  def average_grade(self):
    return sum(self.grades)/len(self.grades)
  def __str__(self) -> str:
    return f"{self.name} have the avg grades {self.average_grade()}"
print(Student("deepak",[1,2,3,4,5]))
# Out:
# deepak have the avg grades 3.0

# %% [markdown]
# Question 13: Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area. Answer:

# %%
class Rectangle:
  def __init__(self):
    self.length = 0
    self.breath = 0
  def set_dimensions(self,length,breath):
    self.length = length
    self.breath = breath
  def area(self):
    return self.length*self.breath
obj = Rectangle()
obj.set_dimensions(10,3)
print("Area of the trangle is ",obj.area())
# Out:
# Area of the trangle is  30

# %% [markdown]
# Question 14: Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary. Answer:

# %%
class Employee:
  def __init__(self,hours_worked,hours_rate) :
    self.hours_worked = hours_worked
    self.hours_rate = hours_rate

  def calculate_salary(self):
    return self.hours_worked*self.hours_rate

class Manager(Employee):

  def __init__(self, hours_worked, hours_rate,bonus):
    super().__init__(hours_worked, hours_rate)
    self.bonus = bonus

  def calculate_salary(self):
      return super().calculate_salary() + self.bonus


m1 = Manager(40, 200, 5000)
print("Manager Salary:", m1.calculate_salary())
# Out:
# Manager Salary: 13000

# %% [markdown]
# Question 15: Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product. Answer:

# %%
from itertools import product
class Product:
  def __init__(self,name,price,quantity) -> None:
    self.name=name
    self.price = price
    self.quantity = quantity
  def total_price(self):
    return self.price* self.quantity
  def __str__(self):
    return f"The total price of  the product {self.name} is {self.total_price()}"
p = Product("iphone",3,1454544)
print(p)
# Out:
# The total price of  the product iphone is 4363632

# %% [markdown]
# Question 16: Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method. Answer:

# %%
from abc import ABC,abstractmethod
class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass
class Cow(Animal):
  def sound(self):
    print("cow say moo")
class Sheep(Animal):
  def sound(self):
    print("Sheep says mahee")
cow = Cow()
cow.sound()

sheep = Sheep()
sheep.sound()
# Out:
# cow say moo
# Sheep says mahee

# %% [markdown]
# Question 17: Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details. Answer:

# %%
class Book:
  def __init__(self,author,title,year_published):
    self.author = author
    self.title = title
    self.year_published = year_published

  def get_book_info(self):
    return f"{self.title} by  {self.author},published in {self.year_published}"
b1 = Book( "James Clear","Atomic Habits", 2018)
print(b1.get_book_info())
# Out:
# Atomic Habits by  James Clear,published in 2018

# %% [markdown]
# Question 18: Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms. Answer:

# %%
from ctypes import addressof
class House:
  def __init__(self,address,price) -> None:
    self.address = address
    self.price = price
class Mansion(House):
  def __init__(self, address, price,number_of_rooms) -> None:
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms
m1 = Mansion("4654 Green Valley, Noida", 7500000, 10)
print(f"Address: {m1.address}")
print(f"Price: ₹{m1.price}")
print(f"Number of Rooms: {m1.number_of_rooms}")
# Out:
# Address: 4654 Green Valley, Noida
# Price: ₹7500000
# Number of Rooms: 10
